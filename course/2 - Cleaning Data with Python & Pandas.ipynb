# %% [markdown]
# # 2 - Cleaning Data with Python & Pandas
#
#
# ### Cleaning Data
#
# It's true that we made this data but let's look at it as if we didn't.
#
# The `Player Salary` column has valid values for US Dollars but there's a key issue with them: they're strings (`str`). In this section, we'll convert this data into a `float` data type.
#
# The next issue is the column names. `Player Name` and `Player Salary` work but I would prefer to name them a bit more pythonic like `name` and `salary` respectively.
#
# Let's start by importing our sample data from `1 - Pandas & Datasets`

# %%
import pandas as pd
import random

# utils.py was created by us
import utils

# %%
# read sample data
df = pd.read_csv("samples/1.csv")

# %% [markdown]
# > Are you missing the sample data? Be sure to [launched this code on Deepnote](https://deepnote.com/launch?url=https://github.com/codingforentrepreneurs/Try-Pandas)

# %% [markdown]
# Now, lets __change the column names__:

# %%
column_name_mapping = {
    "Player Name": "name",
    "Player Salary": "salary"
}

# %%
# we're using the first DataFrame from the top `df`.
renamed_df = df.rename(columns=column_name_mapping)

# %%
renamed_df.head()
# Out:
#        name          salary
# 0  Player-0  $23,564,932.00
# 1  Player-1  $19,122,655.00
# 2  Player-2   $9,926,467.00
# 3  Player-3  $44,055,782.00
# 4  Player-4  $41,113,231.00

# %% [markdown]
# The mapping is pretty simple just use a `key`/`value` pair with the way you want to rename it.
#
# Going forward we'll use the convention `df` instead of `renamed_df` so let's make a copy:

# %%
df = renamed_df.copy()

# %% [markdown]
# Now, let's convert a Dollar `string` into a `float`:

# %%
salary_example = "$30,707,056.00"
salary_replacements = salary_example.replace("$", "").replace(",", "_")
salary_replacements
# Out:
# '30_707_056.00'

# %% [markdown]
# As you see, I replaced commas `,` with underscores `_`. As you may know, you can write large values in Python using underscores to make it more human readable just like `100000000000` becomes `100_000_000_000`

# %%
salary_example_as_float = float(salary_replacements)
salary_example_as_float
# Out:
# 30707056.0

# %% [markdown]
# Now that we have a `float` value, we can do further analysis.
#
# But this is just one hard-coded value. How do we do this in our `DataFrame`? There's actually a few ways to do this. We'll do it by adding a column to our dataset.
#
# Before we can make changes to any given column, let's look at all values in any given column

# %%
df['salary']
# Out:
# 0        $23,564,932.00
# 1        $19,122,655.00
# 2         $9,926,467.00
# 3        $44,055,782.00
# 4        $41,113,231.00
#               ...
# 30247    $25,666,586.00
# 30248       $649,549.00
# 30249    $18,001,656.00
# 30250    $16,715,266.00
# 30251    $28,971,015.00
# Name: salary, Length: 30252, dtype: object

# %% [markdown]
# This shows us:
# - How to grab data via column name (our renamed column of course)
# - An example of Pandas `Series`
# - DataFrame Index Values (based on our data).
#
# All of the above we'll continue to look at in future videos. For now, we need to get *just* the list of values from the column we're getting data from. We'll do that with:

# %%
list(df['salary'].values)
# Out:
# ['$23,564,932.00',
#  '$19,122,655.00',
#  '$9,926,467.00',
#  '$44,055,782.00',
#  '$41,113,231.00',
#  '$38,515,477.00',
#  '$24,941,389.00',
#  '$4,216,796.00',
#  '$38,472,958.00',
#  '$37,072,615.00',
#  '$24,627,994.00',
#  '$15,656,467.00',
#  '$44,230,432.00',
#  '$28,898,355.00',
#  '$9,360,168.00',
#  '$40,550,209.00',
#  '$47,099,973.00',
#  '$44,857,116.00',
#  '$18,961,730.00',
#  '$6,411,070.00',
#  '$22,392,884.00',
#  '$38,419,389.00',
#  '$5,147,141.00',
#  '$14,440,973.00',
#  '$7,987,556.00',
#  '$20,799,362.00',
#  '$36,259,015.00',
#  '$47,256,440.00',
#  '$16,706,382.00',
#  '$26,181,563.00',
#  '$20,982,648.00',
#  '$31,290,916.00',
#  '$45,526,224.00',
#  '$11,161,954.00',
#  '$4,703,055.00',
#  '$4,500,971.00',
#  '$32,615,395.00',
#  '$32,661,868.00',
#  '$13,141,247.00',
#  '$45,928,956.00',
#  '$1,794,957.00',
#  '$29,988,773.00',
#  '$35,721,507.00',
#  '$7,200,865.00',
#  '$44,741,268.00',
#  '$2,035,660.00',
#  '$31,591,784.00',
#  '$14,269,633.00',
#  '$14,685,822.00',
#  '$44,226,547.00',
#  '$20,484,781.00',
#  '$10,309,771.00',
#  '$5,464,299.00',
#  '$15,884,172.00',
#  '$48,155,892.00',
#  '$30,958,364.00',
#  '$8,252,851.00',
#  '$11,937,134.00',
#  '$19,271,965.00',
#  '$24,433,176.00',
#  '$22,254,664.00',
#  '$22,248,516.00',
#  '$28,287,889.00',
#  '$26,329,410.00',
#  '$25,716,286.00',
#  '$36,676,054.00',
#  '$3,502,251.00',
#  '$30,615,303.00',
#  '$10,914,569.00',
#  '$38,700,332.00',
#  '$33,989,418.00',
#  '$49,887,175.00',
#  '$40,143,675.00',
#  '$10,489,167.00',
#  '$37,724,535.00',
#  '$39,281,900.00',
#  '$45,963,678.00',
#  '$5,021,758.00',
#  '$5,285,819.00',
#  '$1,207,458.00',
#  '$36,122,811.00',
#  '$22,091,316.00',
#  '$41,017,086.00',
#  '$2,043,600.00',
#  '$8,584,491.00',
#  '$33,564,149.00',
#  '$43,078,239.00',
#  '$49,101,663.00',
#  '$26,247,227.00',
#  '$12,405,506.00',
#  '$39,305,926.00',
#  '$1,654,474.00',
#  '$48,957,095.00',
#  '$20,777,301.00',
#  '$46,170,592.00',
#  '$38,249,733.00',
#  '$25,241,860.00',
#  '$3,306,859.00',
#  '$23,834,090.00',
#  '$26,746,689.00',
#  '$19,352,078.00',
#  '$22,010,361.00',
#  '$34,667,543.00',
#  '$45,379,053.00',
#  '$6,657,466.00',
#  '$35,268,887.00',
#  '$16,245,453.00',
#  '$37,920,694.00',
#  '$18,410,519.00',
#  '$13,709,915.00',
#  '$45,693,171.00',
#  '$11,716,275.00',
#  '$13,531,813.00',
#  '$20,469,358.00',
#  '$5,060,803.00',
#  '$33,345,147.00',
#  '$43,466,213.00',
#  '$6,443,047.00',
#  '$21,225,246.00',
#  '$32,546,300.00',
#  '$23,204,786.00',
#  '$42,351,342.00',
#  '$46,177,803.00',
#  '$20,260,186.00',
#  '$13,620,120.00',
#  '$14,072,409.00',
#  '$1,010,452.00',
#  '$43,158,502.00',
#  '$5,508,345.00',
#  '$28,813,051.00',
#  '$45,060,665.00',
#  '$34,753,451.00',
#  '$48,086,245.00',
#  '$13,845,403.00',
#  '$21,861,023.00',
#  '$25,056,947.00',
#  '$44,433,298.00',
#  '$27,941,271.00',
#  '$8,247,611.00',
#  '$30,840,211.00',
#  '$28,035,186.00',
#  '$24,190,068.00',
#  '$47,898,027.00',
#  '$627,003.00',
#  '$16,073,233.00',
#  '$25,963,711.00',
#  '$18,964,405.00',
#  '$21,479,189.00',
#  '$45,170,481.00',
#  '$623,092.00',
#  '$33,588,058.00',
#  '$30,316,273.00',
#  '$36,168,581.00',
#  '$21,670,999.00',
#  '$36,608,781.00',
#  '$15,371,768.00',
#  '$9,276,279.00',
#  '$18,880,617.00',
#  '$38,290,691.00',
#  '$41,956,566.00',
#  '$13,092,203.00',
#  '$3,421,015.00',
#  '$29,287,063.00',
#  '$30,885,919.00',
#  '$20,099,569.00',
#  '$1,224,000.00',
#  '$10,501,327.00',
#  '$22,925,621.00',
#  '$49,771,004.00',
#  '$27,864,580.00',
#  '$17,679,526.00',
#  '$28,372,353.00',
#  '$46,729,483.00',
#  '$22,901,294.00',
#  '$13,312,541.00',
#  '$22,425,322.00',
#  '$3,899,270.00',
#  '$2,102,268.00',
#  '$9,298,252.00',
#  '$1,949,491.00',
#  '$35,219,359.00',
#  '$2,820,143.00',
#  '$28,641,582.00',
#  '$10,322,908.00',
#  '$49,834,281.00',
#  '$6,257,842.00',
#  '$11,154,501.00',
#  '$23,942,667.00',
#  '$13,125,004.00',
#  '$31,721,837.00',
#  '$1,740,759.00',
#  '$22,255,415.00',
#  '$8,772,102.00',
#  '$49,279,028.00',
#  '$27,318,594.00',
#  '$14,857,259.00',
#  '$16,498,283.00',
#  '$7,192,833.00',
#  '$28,542,901.00',
#  '$1,173,772.00',
#  '$16,237,752.00',
#  '$9,876,132.00',
#  '$42,995,210.00',
#  '$15,931,539.00',
#  '$278,924.00',
#  '$31,381,317.00',
#  '$27,440,878.00',
#  '$24,956,534.00',
#  '$12,287,439.00',
#  '$26,450,825.00',
#  '$3,729,147.00',
#  '$25,924,204.00',
#  '$6,400,726.00',
#  '$32,120,708.00',
#  '$22,070,153.00',
#  '$48,469,474.00',
#  '$6,827,227.00',
#  '$15,257,529.00',
#  '$34,130,480.00',
#  '$21,039,885.00',
#  '$24,334,543.00',
#  '$38,551,618.00',
#  '$12,547,395.00',
#  '$10,623,779.00',
#  '$29,299,057.00',
#  '$11,291,763.00',
#  '$14,813,274.00',
#  '$30,311,172.00',
#  '$16,934,807.00',
#  '$48,869,428.00',
#  '$33,850,598.00',
#  '$4,371,847.00',
#  '$46,284,254.00',
#  '$8,050,398.00',
#  '$19,880,055.00',
#  '$1,345,242.00',
#  '$195,333.00',
#  '$33,188,149.00',
#  '$5,767,872.00',
#  '$40,173,066.00',
#  '$6,849,779.00',
#  '$18,308,043.00',
#  '$10,605,752.00',
#  '$19,927,701.00',
#  '$9,287,516.00',
#  '$45,265,785.00',
#  '$9,519,748.00',
#  '$28,686,003.00',
#  '$42,533,593.00',
#  '$1,000,497.00',
#  '$32,732,139.00',
#  '$43,650,548.00',
#  '$12,163,786.00',
#  '$8,354,574.00',
#  '$16,155,722.00',
#  '$40,889,055.00',
#  '$43,318,783.00',
#  '$42,083,883.00',
#  '$9,671,634.00',
#  '$4,263,245.00',
#  '$256,027.00',
#  '$26,808,629.00',
#  '$36,214,401.00',
#  '$7,946,546.00',
#  '$17,717,887.00',
#  '$12,466,830.00',
#  '$16,560,343.00',
#  '$29,804,559.00',
#  '$40,854,936.00',
#  '$26,511,099.00',
#  '$16,662,903.00',
#  '$32,746,128.00',
#  '$748,609.00',
#  '$18,395,219.00',
#  '$25,893,214.00',
#  '$18,278,206.00',
#  '$19,897,228.00',
#  '$22,463,596.00',
#  '$45,256,240.00',
#  '$36,203,712.00',
#  '$47,716,797.00',
#  '$32,785,392.00',
#  '$820,274.00',
#  '$20,937,400.00',
#  '$42,918,658.00',
#  '$20,408,647.00',
#  '$18,777,254.00',
#  '$5,429,052.00',
#  '$10,717,931.00',
#  '$13,543,030.00',
#  '$33,420,364.00',
#  '$44,336,728.00',
#  '$6,739,141.00',
#  '$6,395,382.00',
#  '$45,029,179.00',
#  '$37,675,969.00',
#  '$4,945,173.00',
#  '$33,339,428.00',
#  '$11,739,682.00',
#  '$18,522,044.00',
#  '$15,989,051.00',
#  '$30,315,103.00',
#  '$28,458,395.00',
#  '$28,755,916.00',
#  '$46,685,685.00',
#  '$35,598,702.00',
#  '$32,399,318.00',
#  '$30,441,472.00',
#  '$10,505,864.00',
#  '$36,416,399.00',
#  '$14,402,528.00',
#  '$5,774,270.00',
#  '$21,399,341.00',
#  '$46,757,126.00',
#  '$2,037,009.00',
#  '$16,136,916.00',
#  '$37,385,381.00',
#  '$20,404,455.00',
#  '$47,977,410.00',
#  '$42,058,696.00',
#  '$23,542,726.00',
#  '$41,584,981.00',
#  '$11,267,147.00',
#  '$13,860,129.00',
#  '$13,270,920.00',
#  '$26,374,444.00',
#  '$37,921,416.00',
#  '$43,293,293.00',
#  '$43,597,158.00',
#  '$7,765,438.00',
#  '$3,256,970.00',
#  '$35,901,939.00',
#  '$6,944,548.00',
#  '$27,024,426.00',
#  '$22,553,463.00',
#  '$47,107,853.00',
#  '$45,666,707.00',
#  '$9,579,526.00',
#  '$41,752,064.00',
#  '$457,333.00',
#  '$15,633,761.00',
#  '$26,055,691.00',
#  '$41,750,279.00',
#  '$13,424,268.00',
#  '$48,424,072.00',
#  '$2,534,933.00',
#  '$847,517.00',
#  '$17,059,592.00',
#  '$36,325,910.00',
#  '$20,759,710.00',
#  '$15,655,086.00',
#  '$5,522,089.00',
#  '$30,621,741.00',
#  '$29,574,034.00',
#  '$1,909,575.00',
#  '$10,239,778.00',
#  '$39,594,074.00',
#  '$24,741,924.00',
#  '$22,348,004.00',
#  '$34,507,511.00',
#  '$43,017,325.00',
#  '$48,028,412.00',
#  '$4,989,810.00',
#  '$17,259,551.00',
#  '$19,905,937.00',
#  '$31,994,288.00',
#  '$46,153,227.00',
#  '$25,378,850.00',
#  '$26,465,085.00',
#  '$5,156,243.00',
#  '$9,252,404.00',
#  '$6,265,209.00',
#  '$28,340,174.00',
#  '$11,371,917.00',
#  '$8,562,594.00',
#  '$10,398,853.00',
#  '$29,442,190.00',
#  '$1,577,959.00',
#  '$38,057,221.00',
#  '$17,169,398.00',
#  '$45,650,172.00',
#  '$47,256,444.00',
#  '$676,144.00',
#  '$30,178,089.00',
#  '$27,940,759.00',
#  '$8,804,471.00',
#  '$4,632,477.00',
#  '$10,474,778.00',
#  '$25,051,825.00',
#  '$44,096,549.00',
#  '$49,880,069.00',
#  '$45,185,720.00',
#  '$27,953,361.00',
#  '$45,436,888.00',
#  '$25,460,129.00',
#  '$41,763,135.00',
#  '$15,956,434.00',
#  '$36,800,413.00',
#  '$49,266,397.00',
#  '$44,786,650.00',
#  '$34,771,841.00',
#  '$47,096,461.00',
#  '$15,147,023.00',
#  '$28,091,313.00',
#  '$29,174,024.00',
#  '$24,272,569.00',
#  '$10,903,891.00',
#  '$15,647,537.00',
#  '$18,584,845.00',
#  '$46,557,826.00',
#  '$33,817,857.00',
#  '$44,460,825.00',
#  '$46,026,871.00',
#  '$40,190,327.00',
#  '$38,970,337.00',
#  '$8,942,886.00',
#  '$23,675,228.00',
#  '$3,991,550.00',
#  '$6,779,066.00',
#  '$38,127,522.00',
#  '$31,197,996.00',
#  '$30,108,385.00',
#  '$35,415,455.00',
#  '$43,322,979.00',
#  '$26,779,016.00',
#  '$44,473,315.00',
#  '$30,184,268.00',
#  '$22,931,741.00',
#  '$39,338,792.00',
#  '$13,805,781.00',
#  '$16,722,445.00',
#  '$16,423,736.00',
#  '$23,127,647.00',
#  '$12,182,379.00',
#  '$25,144,746.00',
#  '$1,541,533.00',
#  '$29,602,782.00',
#  '$14,900,505.00',
#  '$971,491.00',
#  '$6,349,146.00',
#  '$30,962,946.00',
#  '$47,580,638.00',
#  '$30,976,233.00',
#  '$19,689,127.00',
#  '$21,752,626.00',
#  '$5,874,242.00',
#  '$35,347,627.00',
#  '$41,505,469.00',
#  '$18,470,127.00',
#  '$37,014.00',
#  '$21,224,168.00',
#  '$6,968,217.00',
#  '$6,991,509.00',
#  '$37,899,511.00',
#  '$2,673,516.00',
#  '$10,196,951.00',
#  '$17,330,464.00',
#  '$40,830,187.00',
#  '$31,904,560.00',
#  '$35,406,626.00',
#  '$24,944,039.00',
#  '$17,914,783.00',
#  '$12,369,351.00',
#  '$22,911,365.00',
#  '$29,841,205.00',
#  '$23,300,155.00',
#  '$28,941,602.00',
#  '$34,364,400.00',
#  '$49,950,875.00',
#  '$35,682,360.00',
#  '$40,846,559.00',
#  '$11,084,846.00',
#  '$27,277,887.00',
#  '$28,399,900.00',
#  '$14,794,109.00',
#  '$43,747,254.00',
#  '$36,618,709.00',
#  '$40,114,341.00',
#  '$13,551,549.00',
#  '$23,335,504.00',
#  '$35,199,643.00',
#  '$11,868,642.00',
#  '$25,586,213.00',
#  '$31,140,835.00',
#  '$47,914,414.00',
#  '$1,917,899.00',
#  '$45,907,439.00',
#  '$25,128,183.00',
#  '$20,579,756.00',
#  '$37,298,537.00',
#  '$9,990,046.00',
#  '$46,859,188.00',
#  '$36,066,157.00',
#  '$49,281,368.00',
#  '$30,121,960.00',
#  '$13,873,967.00',
#  '$8,744,196.00',
#  '$35,403,675.00',
#  '$44,018,268.00',
#  '$5,757,934.00',
#  '$25,021,557.00',
#  '$36,411,420.00',
#  '$46,967,239.00',
#  '$20,380,880.00',
#  '$19,691,544.00',
#  '$31,093,228.00',
#  '$30,246,110.00',
#  '$42,789,954.00',
#  '$33,046,498.00',
#  '$32,084,477.00',
#  '$25,383,457.00',
#  '$30,147,708.00',
#  '$24,316,596.00',
#  '$10,641,283.00',
#  '$28,721,079.00',
#  '$19,163,752.00',
#  '$38,980,195.00',
#  '$20,958,218.00',
#  '$31,864,965.00',
#  '$8,579,016.00',
#  '$5,126,272.00',
#  '$24,802,070.00',
#  '$22,759,174.00',
#  '$20,915,554.00',
#  '$756,345.00',
#  '$12,354,990.00',
#  '$42,707,140.00',
#  '$12,875,680.00',
#  '$15,162,141.00',
#  '$30,256,199.00',
#  '$12,078,703.00',
#  '$30,245,156.00',
#  '$41,682,512.00',
#  '$36,934,673.00',
#  '$29,981,118.00',
#  '$28,019,458.00',
#  '$8,605,674.00',
#  '$25,364,485.00',
#  '$3,213,575.00',
#  '$46,748,305.00',
#  '$2,224,585.00',
#  '$47,802,149.00',
#  '$20,107,032.00',
#  '$374,651.00',
#  '$42,506,923.00',
#  '$27,430,134.00',
#  '$20,243,511.00',
#  '$5,449,496.00',
#  '$30,750,717.00',
#  '$36,778,492.00',
#  '$33,488,787.00',
#  '$31,356,774.00',
#  '$8,124,336.00',
#  '$38,969,785.00',
#  '$28,783,975.00',
#  '$49,082,331.00',
#  '$14,929,333.00',
#  '$43,439,739.00',
#  '$19,952,979.00',
#  '$23,607,501.00',
#  '$18,596,152.00',
#  '$933,781.00',
#  '$13,991,873.00',
#  '$11,674,982.00',
#  '$4,025,378.00',
#  '$21,988,049.00',
#  '$35,836,848.00',
#  '$7,044,850.00',
#  '$2,388,990.00',
#  '$45,461,688.00',
#  '$36,603,913.00',
#  '$4,221,274.00',
#  '$2,663,358.00',
#  '$6,765,524.00',
#  '$21,453,134.00',
#  '$12,330,725.00',
#  '$8,055,752.00',
#  '$29,798,749.00',
#  '$23,401,330.00',
#  '$13,433,510.00',
#  '$1,217,564.00',
#  '$43,273,600.00',
#  '$2,710,430.00',
#  '$3,121,404.00',
#  '$4,568,856.00',
#  '$7,033,620.00',
#  '$20,212,462.00',
#  '$18,606,454.00',
#  '$24,457,349.00',
#  '$37,478,142.00',
#  '$42,281,104.00',
#  '$9,960,180.00',
#  '$20,764,421.00',
#  '$31,911,335.00',
#  '$8,683,322.00',
#  '$2,969,550.00',
#  '$31,752,526.00',
#  '$27,989,748.00',
#  '$26,278,937.00',
#  '$30,553,920.00',
#  '$31,903,039.00',
#  '$3,599,579.00',
#  '$34,397,668.00',
#  '$22,760,837.00',
#  '$7,784,585.00',
#  '$15,907,213.00',
#  '$26,177,904.00',
#  '$13,951,293.00',
#  '$32,296,433.00',
#  '$19,947,351.00',
#  '$40,672,310.00',
#  '$18,423,034.00',
#  '$44,436,083.00',
#  '$3,395,953.00',
#  '$14,223,494.00',
#  '$27,137,543.00',
#  '$25,305,289.00',
#  '$31,276,964.00',
#  '$46,594,447.00',
#  '$8,748,392.00',
#  '$10,666,738.00',
#  '$49,618,783.00',
#  '$44,811,234.00',
#  '$46,818,988.00',
#  '$9,575,125.00',
#  '$15,731,683.00',
#  '$22,001,139.00',
#  '$2,290,127.00',
#  '$17,534,902.00',
#  '$32,426,732.00',
#  '$47,264,620.00',
#  '$7,214,372.00',
#  '$43,105,979.00',
#  '$20,464,356.00',
#  '$3,241,597.00',
#  '$10,586,797.00',
#  '$37,050,754.00',
#  '$45,098,688.00',
#  '$10,938,939.00',
#  '$44,624,902.00',
#  '$46,353,972.00',
#  '$14,673,552.00',
#  '$37,159,501.00',
#  '$48,085,989.00',
#  '$30,250,194.00',
#  '$47,276,404.00',
#  '$28,996,282.00',
#  '$27,747,205.00',
#  '$11,339,277.00',
#  '$44,494,433.00',
#  '$29,563,193.00',
#  '$24,838,681.00',
#  '$7,670,273.00',
#  '$48,880,146.00',
#  '$17,004,368.00',
#  '$10,281,114.00',
#  '$46,551,367.00',
#  '$40,300,052.00',
#  '$38,070,558.00',
#  '$45,203,190.00',
#  '$21,703,720.00',
#  '$14,537,658.00',
#  '$35,202,712.00',
#  '$36,741,454.00',
#  '$4,701,046.00',
#  '$35,097,418.00',
#  '$14,551,051.00',
#  '$41,757,991.00',
#  '$49,495,739.00',
#  '$29,445,126.00',
#  '$38,906,038.00',
#  '$22,116,535.00',
#  '$26,155,911.00',
#  '$1,011,252.00',
#  '$3,594,287.00',
#  '$37,850,476.00',
#  '$19,192,116.00',
#  '$41,152,805.00',
#  '$15,214,255.00',
#  '$11,484,549.00',
#  '$40,556,880.00',
#  '$6,051,587.00',
#  '$519,497.00',
#  '$27,518,512.00',
#  '$16,152,224.00',
#  '$42,959,069.00',
#  '$23,871,618.00',
#  '$34,101,866.00',
#  '$2,778,281.00',
#  '$10,812,073.00',
#  '$46,971,491.00',
#  '$39,909,825.00',
#  '$21,955,576.00',
#  '$36,725,856.00',
#  '$36,874,735.00',
#  '$36,236,684.00',
#  '$6,943,248.00',
#  '$23,151,665.00',
#  '$767,744.00',
#  '$30,163,922.00',
#  '$15,616,945.00',
#  '$18,334,839.00',
#  '$38,266,493.00',
#  '$22,763,095.00',
#  '$46,054,243.00',
#  '$18,488,757.00',
#  '$46,150,660.00',
#  '$17,087,109.00',
#  '$38,570,654.00',
#  '$8,779,440.00',
#  '$34,122,836.00',
#  '$18,556,145.00',
#  '$17,382,858.00',
#  '$25,659,041.00',
#  '$44,631,429.00',
#  '$6,066,648.00',
#  '$2,996,808.00',
#  '$16,921,193.00',
#  '$22,501,437.00',
#  '$3,220,778.00',
#  '$20,140,260.00',
#  '$41,602,635.00',
#  '$41,704,197.00',
#  '$43,146,182.00',
#  '$14,001,658.00',
#  '$16,799,059.00',
#  '$20,546,508.00',
#  '$8,949,313.00',
#  '$8,269,307.00',
#  '$10,401,099.00',
#  '$30,553,834.00',
#  '$2,555,865.00',
#  '$3,922,498.00',
#  '$30,878,430.00',
#  '$47,867,406.00',
#  '$38,070,037.00',
#  '$38,505,777.00',
#  '$1,423,496.00',
#  '$16,797,256.00',
#  '$49,675,967.00',
#  '$32,531,705.00',
#  '$7,683,871.00',
#  '$47,138,966.00',
#  '$23,770,170.00',
#  '$8,824,094.00',
#  '$9,805,056.00',
#  '$7,540,576.00',
#  '$35,632,111.00',
#  '$44,013,512.00',
#  '$23,737,912.00',
#  '$37,419,254.00',
#  '$7,581,913.00',
#  '$48,381,010.00',
#  '$43,768,533.00',
#  '$20,114,963.00',
#  '$33,358,419.00',
#  '$11,588,256.00',
#  '$17,668,896.00',
#  '$5,166,160.00',
#  '$28,638,650.00',
#  '$11,881,680.00',
#  '$4,181,835.00',
#  '$46,718,112.00',
#  '$39,548,105.00',
#  '$42,807,740.00',
#  '$23,888,215.00',
#  '$24,241,063.00',
#  '$2,653,409.00',
#  '$16,975,363.00',
#  '$29,826,975.00',
#  '$14,730,481.00',
#  '$19,044,003.00',
#  '$48,348,493.00',
#  '$11,583,036.00',
#  '$30,393,948.00',
#  '$39,943,785.00',
#  '$10,152,972.00',
#  '$49,385,052.00',
#  '$20,855,742.00',
#  '$7,395,207.00',
#  '$2,125,446.00',
#  '$41,039,728.00',
#  '$43,948,212.00',
#  '$26,484,073.00',
#  '$43,212,130.00',
#  '$7,115,758.00',
#  '$19,961,768.00',
#  '$45,302,252.00',
#  '$17,985,729.00',
#  '$20,438,241.00',
#  '$42,901,053.00',
#  '$45,521,106.00',
#  '$25,307,806.00',
#  '$32,273,601.00',
#  '$2,325,006.00',
#  '$8,275,472.00',
#  '$47,072,595.00',
#  '$35,327,043.00',
#  '$25,587,626.00',
#  '$41,536,056.00',
#  '$4,207,803.00',
#  '$26,028,723.00',
#  '$31,943,790.00',
#  '$33,709,848.00',
#  '$43,931,337.00',
#  '$22,334,324.00',
#  '$1,270,931.00',
#  '$7,679,560.00',
#  '$31,185,045.00',
#  '$16,881,505.00',
#  '$36,352,792.00',
#  '$49,572,301.00',
#  '$6,314,008.00',
#  '$11,333,762.00',
#  '$33,066,041.00',
#  '$10,214,154.00',
#  '$28,680,715.00',
#  '$734,892.00',
#  '$40,309,725.00',
#  '$30,282,722.00',
#  '$21,917,037.00',
#  '$23,984,629.00',
#  '$42,653,095.00',
#  '$8,547,932.00',
#  '$23,921,085.00',
#  '$28,412,447.00',
#  '$16,954,567.00',
#  '$23,599,982.00',
#  '$45,916,744.00',
#  '$24,728,923.00',
#  '$34,076,480.00',
#  '$47,663,079.00',
#  '$39,731,232.00',
#  '$35,797,170.00',
#  '$22,568,736.00',
#  '$49,990,134.00',
#  '$41,238,129.00',
#  '$26,285,726.00',
#  '$48,437,358.00',
#  '$40,727,711.00',
#  '$19,010,091.00',
#  '$46,445,541.00',
#  '$38,493,350.00',
#  '$29,907,009.00',
#  '$35,321,287.00',
#  '$25,015,299.00',
#  '$28,099,830.00',
#  '$13,474,281.00',
#  '$46,382,629.00',
#  '$6,675,419.00',
#  '$811,948.00',
#  '$48,604,572.00',
#  '$9,197,634.00',
#  '$19,121,577.00',
#  '$43,315,754.00',
#  '$41,810,682.00',
#  '$48,045,010.00',
#  '$34,717,148.00',
#  '$40,738,875.00',
#  '$24,103,798.00',
#  '$15,447,705.00',
#  '$20,007,481.00',
#  '$16,224,994.00',
#  '$42,533,793.00',
#  '$29,628,089.00',
#  '$42,072,796.00',
#  '$25,900,865.00',
#  '$3,932,029.00',
#  '$23,292,862.00',
#  '$17,372,873.00',
#  '$46,563,480.00',
#  '$39,180,206.00',
#  '$42,594,627.00',
#  '$43,060,662.00',
#  '$18,374,886.00',
#  '$25,002,870.00',
#  '$30,521,322.00',
#  '$31,002,611.00',
#  '$29,928,371.00',
#  '$3,360,855.00',
#  '$48,283,852.00',
#  '$37,848,335.00',
#  '$15,853,812.00',
#  '$25,044,863.00',
#  '$35,828,445.00',
#  '$24,510,510.00',
#  '$35,763,271.00',
#  '$28,198,873.00',
#  '$39,867,900.00',
#  '$48,122,134.00',
#  '$17,426,481.00',
#  '$20,574,572.00',
#  '$25,948,236.00',
#  '$9,784,275.00',
#  '$21,582,207.00',
#  '$45,121,356.00',
#  '$18,851,777.00',
#  '$42,544,844.00',
#  '$43,459,862.00',
#  '$12,138,250.00',
#  '$14,415,539.00',
#  '$34,412,938.00',
#  '$10,645,489.00',
#  '$20,792,557.00',
#  '$5,401,509.00',
#  '$5,716,396.00',
#  '$8,118,030.00',
#  '$20,595,633.00',
#  '$45,940,359.00',
#  '$32,989,128.00',
#  '$20,392,865.00',
#  '$11,124,353.00',
#  '$11,383,609.00',
#  '$27,536,533.00',
#  '$28,737,925.00',
#  '$21,705,926.00',
#  '$33,684,796.00',
#  '$1,902,368.00',
#  '$27,762,153.00',
#  '$41,038,900.00',
#  '$44,375,917.00',
#  '$15,006,197.00',
#  '$28,547,388.00',
#  '$44,952,918.00',
#  '$1,513,089.00',
#  '$1,267,255.00',
#  '$31,446,169.00',
#  '$18,237,608.00',
#  '$48,080,090.00',
#  '$22,119,908.00',
#  '$49,609,226.00',
#  '$17,117,316.00',
#  '$29,558,770.00',
#  '$31,353,765.00',
#  '$38,761,316.00',
#  '$18,766,502.00',
#  '$28,403,719.00',
#  '$40,748,303.00',
#  '$31,182,614.00',
#  '$30,924,630.00',
#  '$20,698,997.00',
#  '$24,998,716.00',
#  '$29,912,612.00',
#  '$20,597,068.00',
#  '$15,301,385.00',
#  '$11,540,473.00',
#  '$30,884,214.00',
#  '$14,794,493.00',
#  '$37,632,547.00',
#  '$25,521,791.00',
#  '$252,813.00',
#  '$46,085,950.00',
#  '$43,132,407.00',
#  '$31,495,520.00',
#  '$1,587,590.00',
#  '$18,189,007.00',
#  '$10,847,389.00',
#  '$4,805,929.00',
#  '$15,791,249.00',
#  '$16,081,753.00',
#  '$33,643,916.00',
#  '$23,657,485.00',
#  '$2,359,349.00',
#  '$24,397,829.00',
#  '$11,381,541.00',
#  '$22,310,343.00',
#  '$42,607,614.00',
#  '$31,383,553.00',
#  '$49,083,223.00',
#  '$35,380,078.00',
#  '$15,288,038.00',
#  '$11,187,330.00',
#  '$14,303,219.00',
#  '$7,247,600.00',
#  '$16,995,609.00',
#  '$701,036.00',
#  '$45,662,213.00',
#  '$93,102.00',
#  '$12,852,552.00',
#  '$9,754,388.00',
#  '$33,925,594.00',
#  '$19,048,726.00',
#  '$12,423,672.00',
#  '$43,877,674.00',
#  '$17,989,132.00',
#  '$1,672,002.00',
#  '$45,943,000.00',
#  '$42,626,703.00',
#  '$18,851,445.00',
#  '$21,386,498.00',
#  '$47,358,381.00',
#  '$31,084,831.00',
#  '$10,201,414.00',
#  '$28,717,807.00',
#  '$41,194,617.00',
#  '$5,007,080.00',
#  '$9,163,643.00',
#  '$33,370,769.00',
#  '$11,045,757.00',
#  '$14,068,095.00',
#  ...]

# %% [markdown]
# So how would we convert all this data in pure python? Perhaps something like:

# %%
values = list(df['salary'].values)
new_values = []
for val in values:
    new_val = float(val.replace("$", "").replace(",", "_"))
    # you can also use new_val = utils.float_to_dollars(val)
    new_values.append(new_val)

print(new_values)
# Out:
# [23564932.0, 19122655.0, 9926467.0, 44055782.0, 41113231.0, 38515477.0, 24941389.0, 4216796.0, 38472958.0, 37072615.0, 24627994.0, 15656467.0, 44230432.0, 28898355.0, 9360168.0, 40550209.0, 47099973.0, 44857116.0, 18961730.0, 6411070.0, 22392884.0, 38419389.0, 5147141.0, 14440973.0, 7987556.0, 20799362.0, 36259015.0, 47256440.0, 16706382.0, 26181563.0, 20982648.0, 31290916.0, 45526224.0, 11161954.0, 4703055.0, 4500971.0, 32615395.0, 32661868.0, 13141247.0, 45928956.0, 1794957.0, 29988773.0, 35721507.0, 7200865.0, 44741268.0, 2035660.0, 31591784.0, 14269633.0, 14685822.0, 44226547.0, 20484781.0, 10309771.0, 5464299.0, 15884172.0, 48155892.0, 30958364.0, 8252851.0, 11937134.0, 19271965.0, 24433176.0, 22254664.0, 22248516.0, 28287889.0, 26329410.0, 25716286.0, 36676054.0, 3502251.0, 30615303.0, 10914569.0, 38700332.0, 33989418.0, 49887175.0, 40143675.0, 10489167.0, 37724535.0, 39281900.0, 45963678.0, 5021758.0, 5285819.0, 1207458.0, 36122811.0, 22091316.0, 41017086.0, 2043600.0, 8584491.0, 33564149.0, 43078239.0, 49101663.0, 26247227.0, 12405506.0, 39305926.0, 1654474.0, 48957095.0, 20777301.0, 46170592.0, 38249733.0, 25241860.0, 3306859.0, 23834090.0, 26746689.0, 19352078.0, 22010361.0, 34667543.0, 45379053.0, 6657466.0, 35268887.0, 16245453.0, 37920694.0, 18410519.0, 13709915.0, 45693171.0, 11716275.0, 13531813.0, 20469358.0, 5060803.0, 33345147.0, 43466213.0, 6443047.0, 21225246.0, 32546300.0, 23204786.0, 42351342.0, 46177803.0, 20260186.0, 13620120.0, 14072409.0, 1010452.0, 43158502.0, 5508345.0, 28813051.0, 45060665.0, 34753451.0, 48086245.0, 13845403.0, 21861023.0, 25056947.0, 44433298.0, 27941271.0, 8247611.0, 30840211.0, 28035186.0, 24190068.0, 47898027.0, 627003.0, 16073233.0, 25963711.0, 18964405.0, 21479189.0, 45170481.0, 623092.0, 33588058.0, 30316273.0, 36168581.0, 21670999.0, 36608781.0, 15371768.0, 9276279.0, 18880617.0, 38290691.0, 41956566.0, 13092203.0, 3421015.0, 29287063.0, 30885919.0, 20099569.0, 1224000.0, 10501327.0, 22925621.0, 49771004.0, 27864580.0, 17679526.0, 28372353.0, 46729483.0, 22901294.0, 13312541.0, 22425322.0, 3899270.0, 2102268.0, 9298252.0, 1949491.0, 35219359.0, 2820143.0, 28641582.0, 10322908.0, 49834281.0, 6257842.0, 11154501.0, 23942667.0, 13125004.0, 31721837.0, 1740759.0, 22255415.0, 8772102.0, 49279028.0, 27318594.0, 14857259.0, 16498283.0, 7192833.0, 28542901.0, 1173772.0, 16237752.0, 9876132.0, 42995210.0, 15931539.0, 278924.0, 31381317.0, 27440878.0, 24956534.0, 12287439.0, 26450825.0, 3729147.0, 25924204.0, 6400726.0, 32120708.0, 22070153.0, 48469474.0, 6827227.0, 15257529.0, 34130480.0, 21039885.0, 24334543.0, 38551618.0, 12547395.0, 10623779.0, 29299057.0, 11291763.0, 14813274.0, 30311172.0, 16934807.0, 48869428.0, 33850598.0, 4371847.0, 46284254.0, 8050398.0, 19880055.0, 1345242.0, 195333.0, 33188149.0, 5767872.0, 40173066.0, 6849779.0, 18308043.0, 10605752.0, 19927701.0, 9287516.0, 45265785.0, 9519748.0, 28686003.0, 42533593.0, 1000497.0, 32732139.0, 43650548.0, 12163786.0, 8354574.0, 16155722.0, 40889055.0, 43318783.0, 42083883.0, 9671634.0, 4263245.0, 256027.0, 26808629.0, 36214401.0, 7946546.0, 17717887.0, 12466830.0, 16560343.0, 29804559.0, 40854936.0, 26511099.0, 16662903.0, 32746128.0, 748609.0, 18395219.0, 25893214.0, 18278206.0, 19897228.0, 22463596.0, 45256240.0, 36203712.0, 47716797.0, 32785392.0, 820274.0, 20937400.0, 42918658.0, 20408647.0, 18777254.0, 5429052.0, 10717931.0, 13543030.0, 33420364.0, 44336728.0, 6739141.0, 6395382.0, 45029179.0, 37675969.0, 4945173.0, 33339428.0, 11739682.0, 18522044.0, 15989051.0, 30315103.0, 28458395.0, 28755916.0, 46685685.0, 35598702.0, 32399318.0, 30441472.0, 10505864.0, 36416399.0, 14402528.0, 5774270.0, 21399341.0, 46757126.0, 2037009.0, 16136916.0, 37385381.0, 20404455.0, 47977410.0, 42058696.0, 23542726.0, 41584981.0, 11267147.0, 13860129.0, 13270920.0, 26374444.0, 37921416.0, 43293293.0, 43597158.0, 7765438.0, 3256970.0, 35901939.0, 6944548.0, 27024426.0, 22553463.0, 47107853.0, 45666707.0, 9579526.0, 41752064.0, 457333.0, 1 ...

# %% [markdown]
# Let's bare something in mind here: the position (or index) of each value should correspond to it's counterpoint in our table values (ie `new_values[312]` should be the same as `values[312]`). Let's test that here:

# %%
random_index = random.randint(0, len(values))
new_value_via_index = new_values[random_index]
new_value_in_dollars = utils.float_to_dollars(new_value_via_index)

assert new_value_in_dollars == values[random_index]

# %% [markdown]
# Now, let's add these values as a new column in our DataFrame

# %%
df['salary_raw_py'] = new_values
df.head()
# Out:
#        name          salary  salary_raw_py
# 0  Player-0  $23,564,932.00     23564932.0
# 1  Player-1  $19,122,655.00     19122655.0
# 2  Player-2   $9,926,467.00      9926467.0
# 3  Player-3  $44,055,782.00     44055782.0
# 4  Player-4  $41,113,231.00     41113231.0

# %% [markdown]
# Now we can add new columns to a Pandas DataFrame using a familiar method (much like adding a new key to a Python dictionary `dict()`). In this case, the length of the values we added matches the length of all the rows in our DataFrame. We know this because the data *came from the dataframe* in the first place.
#
# Let's try to add arbitrary data.

# %%
import datetime

this_year =  datetime.datetime.now().year # notice this 
df['year'] = this_year

# %%
df.head()
# Out:
#        name          salary  salary_raw_py  year
# 0  Player-0  $23,564,932.00     23564932.0  2021
# 1  Player-1  $19,122,655.00     19122655.0  2021
# 2  Player-2   $9,926,467.00      9926467.0  2021
# 3  Player-3  $44,055,782.00     44055782.0  2021
# 4  Player-4  $41,113,231.00     41113231.0  2021

# %% [markdown]
# So we now see two properties of a DataFrame that are pretty cool. You can add a new column with 1 value or with matching number of row values.
#
# How about data that was 1/2 the number of rows?

# %%
rows_length = df.shape[0]
# column_length = df.shape [1]
half_rows = int(rows_length * 0.5)
try:
    df['is_new'] = [True for x in range(0, half_rows)]
except Exception as e:
    print(e)
# Out:
# Length of values (15126) does not match length of index (30252)

# %% [markdown]
# Now we see that you can:
# - Add a value for all rows from 1 value
# - Add a value fro all rows from a corresponding index value in another list
#
# Everything we did above technically works but it adds a lot of uncessary steps that we can skip thanks to Pandas awesomeness.

# %%
def dollar_str_to_float(val):
    # in the future, this will be stored in
    # utils.py in the courses/ directory
    return float(val.replace("$", "").replace(",", "_"))

df['salary_as_float'] = df['salary'].apply(dollar_str_to_float)

# %% [markdown]
# Let's break this down:
# - `df['salary_via_apply']` is declaring our new column
# - `df['salary']` is a reference to the values in a pre-existing column on this dataframe
# - `.apply()` will run a function on *all* values in the referenced column.
# - `dollar_str_to_float` is a function that we pass the values to in order to get the correct result.
# - The original `df['salary']` remains unchanged.

# %%
df.head()
# Out:
#        name          salary  salary_raw_py  year  salary_as_float
# 0  Player-0  $23,564,932.00     23564932.0  2021       23564932.0
# 1  Player-1  $19,122,655.00     19122655.0  2021       19122655.0
# 2  Player-2   $9,926,467.00      9926467.0  2021        9926467.0
# 3  Player-3  $44,055,782.00     44055782.0  2021       44055782.0
# 4  Player-4  $41,113,231.00     41113231.0  2021       41113231.0

# %% [markdown]
# You can also use a lambda to simplify this further:
#
# ```python
# df['salary_via_apply_lambda'] = df['salary'].apply(lambda x: float(x.replace('$', '').replace(',', '')))
# ```

# %%
# Export to samples dir
# df.to_csv("samples/2.csv", index=False)
